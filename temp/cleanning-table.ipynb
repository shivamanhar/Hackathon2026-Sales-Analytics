# %%
# %run ../config/metadata_setup

# %%
dbutils.fs.rm(f"{CONFIG['paths']['checkpoints']}", True)

# %%
dbutils.fs.rm(f"{CONFIG['paths']['schemas']}", True)

# %%
spark.sql(f"use catalog {CONFIG['catalog']['name']}")

# %%
spark.sql(f"use schema {CONFIG['catalog']['schema']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['bronze']['orders']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['bronze']['order_details']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['bronze']['sales_target']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['silver']['orders']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['silver']['order_details']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['silver']['sales_target']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['silver']['return_orders']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['silver']['actual_orders']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['gold']['sales_facts']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['gold']['daily_order_metrics']}")

# %%
spark.sql(f"DROP TABLE  {TABLES['gold']['profit_target_metrics']}")
