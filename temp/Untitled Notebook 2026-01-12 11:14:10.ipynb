# %%
# %sql
select *from csv.`/Volumes/wipro_hackathon_2026/sh20508860/hackathon_raw_vol/orders/`

# %%
# %sql
select *from csv.`/Volumes/wipro_hackathon_2026/sh20508860/hackathon_raw_vol/order_details`

# %%
# %sql
select count(1) from csv.`/Volumes/wipro_hackathon_2026/sh20508860/hackathon_raw_vol/order_details`

# %%
# %sql
select * from csv.`dbfs:/Volumes/wipro_hackathon_2026/sh20508860/hackathon_raw_vol/sales_target`

# %%
# %sql
select count(1) as total_order, order_date from wipro_hackathon_2026.sh20508860.silver_orders group by order_date order by 1 desc;

# %%
# %sql
select * from wipro_hackathon_2026.sh20508860.silver_actual_orders
